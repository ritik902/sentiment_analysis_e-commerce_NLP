# %% [markdown]
# Import dependencies and doing some preprocessing

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("flipkart_product.csv",encoding='latin-1')  # dataset is not udf-8 so using encoding latin-1

# %%
data.head()
# Out:
#                                          ProductName     Price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 1  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 2  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 3  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    1
# 4  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
#
#             Review                                            Summary
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product

# %% [markdown]
# Checking null values

# %%
data.isnull().sum()
# Out:
# ProductName     0
# Price           1
# Rate            1
# Review          4
# Summary        14
# dtype: int64

# %% [markdown]
# Price only have 1 null value so we will remove it
# Rate also have 1 null value so remove it
# for review and summary we will fill null values as no review and no summary accordingly.

# %% [markdown]
# Filling null values of review and summary column

# %%
data['Review'] = data['Review'].fillna('No review')
data['Summary'] = data['Summary'].fillna('No summary')

# %%
data.isnull().sum()
# Out:
# ProductName    0
# Price          1
# Rate           1
# Review         0
# Summary        0
# dtype: int64

# %%
df=data.dropna()

# %%
df.isnull().sum()
# Out:
# ProductName    0
# Price          0
# Rate           0
# Review         0
# Summary        0
# dtype: int64

# %% [markdown]
# Get summary of our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189873 entries, 0 to 189872
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ProductName  189873 non-null  object
#  1   Price        189873 non-null  object
#  2   Rate         189873 non-null  object
#  3   Review       189873 non-null  object
#  4   Summary      189873 non-null  object
# dtypes: object(5)
# memory usage: 8.7+ MB

# %%
df.shape
# Out:
# (189873, 5)

# %% [markdown]
# Dropping duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (165012, 5)

# %%
import nltk
nltk.download('stopwords')

# %% [markdown]
# Removing stop words from textual data is a common preprocessing step in Natural Language Processing (NLP). Stop words are common words that do not carry significant meaning and are usually removed to focus on the important words in the text.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# %% [markdown]
# A function to remove stop words from each row of summary column

# %%
def remove_stop_words(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
    return ' '.join(filtered_text)

# %%
df['Summary'] = df['Summary'].astype(str).apply(remove_stop_words)

# %%
df.head(10)
# Out:
#                                          ProductName     Price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 1  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 2  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 3  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    1
# 4  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 5  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 6  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 7  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 8  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    1
# 9  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    4
#
#                Review                                            Summary
# 0              Super!  Great cooler .. excellent air flow price . 's ...
# 1             Awesome            Best budget 2 fit cooler . Nice cooling
# 2                Fair                      quality good power air decent
# 3     Useless product                                 bad product 's fan
# 4                Fair                                      Ok ok product
# 5             Awesome  cooler really fantastic provides good air flow...
# 6  Highly recommended                                       good product
# 7                Nice                                               nice
# 8      Unsatisfactory                                         bad cooler
# 9     Worth the money                                               good

# %% [markdown]
# Saving the clean dataset without stop words in summary column

# %%
df.to_csv("flipkart_product_cleaned_stopwords.csv", index=False)

# %%
pip install wordcloud matplotlib

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# Join the data of summary column to a list so that we can make a wordcloud chart

# %%
text = " ".join(df['Summary'].tolist())

# %%
r=df['Summary'].tolist()
print(r[0:5])
# Out:
# ["Great cooler .. excellent air flow price . 's amazing unbelievable.Just love \x83\x9d ? \x8b ? \x8f", 'Best budget 2 fit cooler . Nice cooling', 'quality good power air decent', "bad product 's fan", 'Ok ok product']

# %%
r=text.split(",")
r[0:10]
# Out:
# ["Great cooler .. excellent air flow price . 's amazing unbelievable.Just love \x83\x9d ? \x8b ? \x8f Best budget 2 fit cooler . Nice cooling quality good power air decent bad product 's fan Ok ok product cooler really fantastic provides good air flow . Highly recommended good product nice bad cooler good Beautiful product good material perfectly working Awesome Good Wonderful product ",
#  ' Must buy Nice air cooler ',
#  ' smart cool breeze producer Awsm Nice product ? ? ? \x8d Great cooler .. Nice product Good ? ? ? \x8d nice product ? ? ? ? ? ? ? \x8d Good product Nice product reasonable price like ... \x83\x9d\x9c\x8b ? \x8f goodd Good product Good product kawaleti good cooler amazing beautiful designs affordable price Using since 3months . Great experience . good performance nice look Product good strong thrust air flow .. Must buy good ? ? ? \x8d Bad quality nice ? ? ? \x8d product soundless product low price company Nice best poduct bought flifkart works superb like ac price also reasonable rs 8698 cooler big wide . maharaja brand trust ( ) every thing good cooler ',
#  ' create less noise . thing motor powerful even high speed rest things good ',
#  " .but yes one middle size room ok one best air coolers reasonable price ever seen ventilation room must proper cooling size quite big hope create space problem seasons ... air supply good 's one essential part air cooler wool wood pads helps make super cooling .... Afterall thank Maharaja company make product affordable reasonable price Awesome Air coolerI looking cooler range fulfilled requirement . following features:1 ) Great Air capacity 5000 m3/hr 2 ) Comes large 65-litre tank run overnight ease.3 ) Great built shockproof reliable material.4 ) stop beast night massive cooling capability.One small concern mine sure deal-breaker produces ... Purchased lot discussions reviews . would say best gives comfort needed . Best 2nd thoughts . Nice cooling ",
#  " low noise . Hope energy efficient used long run ... nice cooler . Cooling good noise . reviewed lot purchased . want effective cooling set window cross ventilation . Without cross ventilation make environment humid . Lookwise nice material strong . feedback given using one week .. cooler amazing 's making whole room cooling .. install cooler near windows .. & delivery time well .the delivery boy also supportive Great deal .. 65 l quite big tank . Sufficient Cooling one medium size room .. 3 modes works well .. best range bought cooler heavy discount flipkart . Cooler build good quality material . fast fan powerfull motor pump . Air quality Excellent even big room . must buy value money product . Good things1 . well packed . Good amount thermocols protect transport damages2 . Sturdy body3 . Relatively less noise compared Bajaj cooler earlierWish betterFor many purposes ",
#  ' necessary open Cooler body . Opening body cooler intuitive . Common consumers may even attempt fear damaging something . 1 . Easy opening side frames change pads ',
#  ' clean water inlets2 . Water balloon used cut water supply au ... Excellent product .. Happy result .... Nice air flow ... Osm cooling ..... cooler Works Fine Inverter Friendly Small wire moter capacity low fan speed good ',
#  ' flow vent hole lower part cooler ',
#  " 's difficult change water . Perfect product large size room . Average cooling much expected size reviews cooler ... cooling sufficient Maharaja whiteline work cooling efficiency reduce size width increase height maintain tank capacity . Product amazing .. cooling capacity awsum . Pls go ahead .. big thumbs ? good Received dalay 10 days "]

# %%
p=[s.split(" ") for s in r]
p[0:10]
# Out:
# [['Great',
#   'cooler',
#   '..',
#   'excellent',
#   'air',
#   'flow',
#   'price',
#   '.',
#   "'s",
#   'amazing',
#   'unbelievable.Just',
#   'love',
#   '\x83\x9d',
#   '?',
#   '\x8b',
#   '?',
#   '\x8f',
#   'Best',
#   'budget',
#   '2',
#   'fit',
#   'cooler',
#   '.',
#   'Nice',
#   'cooling',
#   'quality',
#   'good',
#   'power',
#   'air',
#   'decent',
#   'bad',
#   'product',
#   "'s",
#   'fan',
#   'Ok',
#   'ok',
#   'product',
#   'cooler',
#   'really',
#   'fantastic',
#   'provides',
#   'good',
#   'air',
#   'flow',
#   '.',
#   'Highly',
#   'recommended',
#   'good',
#   'product',
#   'nice',
#   'bad',
#   'cooler',
#   'good',
#   'Beautiful',
#   'product',
#   'good',
#   'material',
#   'perfectly',
#   'working',
#   'Awesome',
#   'Good',
#   'Wonderful',
#   'product',
#   ''],
#  ['', 'Must', 'buy', 'Nice', 'air', 'cooler', ''],
#  ['',
#   'smart',
#   'cool',
#   'breeze',
#   'producer',
#   'Awsm',
#   'Nice',
#   'product',
#   '?',
#   '?',
#   '?',
#   '\x8d',
#   'Great',
#   'cooler',
#   '..',
#   'Nice',
#   'product',
#   'Good',
#   '?',
#   '?',
#   '?',
#   '\x8d',
#   'nice',
#   'product',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '\x8d',
#   'Good',
#   'product',
#   'Nice',
#   'product',
#   'reasonable',
#   'price',
#   'like',
#   '...',
#   '\x83\x9d\x9c\x8b',
#   '?',
#   '\x8f',
#   'goodd',
#   'Good',
#   'product',
#   'Good',
#   'product',
#   'kawaleti',
#   'good',
#   'cooler',
#   'amazing',
#   'beautiful',
#   'designs',
#   'affordable',
#   'price',
#   'Using',
#   'since',
#   '3months',
#   '.',
#   'Great',
#   'experience',
#   '.',
#   'good',
#   'performance',
#   'nice',
#   'look',
#   'Product',
#   'good',
#   'strong',
#   'thrust',
#   'air',
#   'flow',
#   '..',
#   'Must',
#   'buy',
#   'good',
#   '?',
#   '?',
#   '?',
#   '\x8d',
#   'Bad',
#   'quality',
#   'nice',
#   '?',
#   '?',
#   '?',
#   '\x8d',
#   'product',
#   'soundless',
#   'product',
#   'low',
#   'price',
#   'company',
#   'Nice',
#   'best',
#   'poduct',
#   'bought',
#   'flifkart',
#   'works',
#   'superb',
#   'like',
#   'ac',
#   'price',
#   'also',
#   'reasonable',
#   'rs',
#   '8698',
#   'cooler',
#   'big',
#   'wide',
#   '.',
#   'maharaja',
#   'brand',
#   'trust',
#   '(',
#   ')',
#   'every',
#   'thing',
#   'good',
#   'cooler',
#   ''],
#  ['',
#   'create',
#   'less',
#   'noise',
#   '.',
#   'thing',
#   'motor',
#   'powerful',
#   'even',
#   'high',
#   'speed',
#   'rest',
#   'things',
#   'good',
#   ''],
#  ['',
#   '.but',
#   'yes',
#   'one',
#   'middle',
#   'size',
#   'room',
#   'ok',
#   'one',
#   'best',
#   'air',
#   'coolers',
#   'reasonable',
#   'price',
#   'ever',
#   'seen',
#   'ventilation',
#   'room',
#   'must',
#   'proper',
#   'cooling',
#   'size',
#   'quite',
#   'big',
#   'hope',
#   'create',
#   'space',
#   'problem',
#   'seasons',
#   '...',
#   'air',
#   'supply',
#   'good',
#   "'s",
#   'one',
#   'essential',
#   'part',
#   'air',
#   'cooler',
#   'wool',
#   'wood',
#   'pads',
#   'helps',
#   'make',
#   'super',
#   'cooling',
#   '....',
#   'Afterall',
#   'thank',
#   'Maharaja',
#   'company',
#   'make',
#   'product',
#   'affordable',
#   'reasonable',
#   'price',
#   'Awesome',
#   'Air',
#   'coolerI',
#   'looking',
#   'cooler',
#   'range',
#   'fulfilled',
#   'requirement',
#   '.',
#   'following',
#   'features:1',
#   ')',
#   'Great',
#   'Air',
#   'capacity',
#   '5000',
#   'm3/hr',
#   '2',
#   ')',
#   'Comes',
#   'large',
#   '65-litre',
#   'tank',
#   'run',
#   'overnight',
#   'ease.3',
#   ')',
#   'Great',
#   'built',
#   'shockproof',
#   'reliable',
#   'material.4',
#   ')',
#   'stop',
#   'beast',
#   'night',
#   'massive',
#   'cooling',
#   'capability.One',
#   'small',
#   'concern',
#   'mine',
#   'sure',
#   'deal-breaker',
#   'produces',
#   '...',
#   'Purchased',
#   'lot',
#   'discussions',
#   'reviews',
#   '.',
#   'would',
#   'say',
#   'best',
#   'gives',
#   'comfort',
#   'needed',
#   '.',
#   'Best',
#   '2nd',
#   'thoughts',
#   '.',
#   'Nice',
#   'cooling',
#   ''],
#  ['',
#   'low',
#   'noise',
#   '.',
#   'Hope',
#   'energy',
#   'efficient',
#   'used',
#   'long',
#   'run',
#   '...',
#   'nice',
#   'cooler',
#   '.',
#   'Cooling',
#   'good',
#   'noise',
#   '.',
#   'reviewed',
#   'lot',
#   'purchased',
#   '.',
#   'want',
#   'effective',
#   'cooling',
#   'set',
#   'window',
#   'cross',
#   'ventilation',
#   '.',
#   'Without',
#   'cross',
#   'ventilation',
#   'make',
#   'environment',
#   'humid',
#   '.',
#   'Lookwise',
#   'nice',
#   'material',
#   'strong',
#   '.',
#   'feedback',
#   'given',
#   'using',
#   'one',
#   'week',
#   '..',
#   'cooler',
#   'amazing',
#   "'s",
#   'making',
#   'whole',
#   'room',
#   'cooling',
#   '..',
#   'install',
#   'cooler',
#   'near',
#   'windows',
#   '..',
#   '&',
#   'delivery',
#   'time',
#   'well',
#   '.the',
#   'delivery',
#   'boy',
#   'also',
#   'supportive',
#   'Great',
#   'deal',
#   '..',
#   '65',
#   'l',
#   'quite',
#   'big',
#   'tank',
#   '.',
#   'Sufficient',
#   'Cooling',
#   'one',
#   'medium',
#   'size',
#   'room',
#   '..',
#   '3',
#   'modes',
#   'works',
#   'well',
#   '..',
#   'best',
#   'range',
#   'bought',
#   'cooler',
#   'heavy',
#   'discount',
#   'flipkart',
#   '.',
#   'Cooler',
#   'build',
#   'good',
#   'quality',
#   'material',
#   '.',
#   'fast',
#   'fan',
#   'powerfull',
#   'motor',
#   'pump',
#   '.',
#   'Air',
#   'quality',
#   'Excellent',
#   'even',
#   'big',
#   'room',
#   '.',
#   'must',
#   'buy',
#   'value',
#   'money',
#   'product',
#   '.',
#   'Good',
#   'things1',
#   '.',
#   'well',
#   'packed',
#   '.',
#   'Good',
#   'amount',
#   'thermocols',
#   'protect',
#   'transport',
#   'damages2',
#   '.',
#   'Sturdy',
#   'body3',
#   '.',
#   'Relatively',
#   'less',
#   'noise',
#   'compared',
#   'Bajaj',
#   'cooler',
#   'earlierWish',
#   'betterFor',
#   'many',
#   'purposes',
#   ''],
#  ['',
#   'necessary',
#   'open',
#   'Cooler',
#   'body',
#   '.',
#   'Opening',
#   'body',
#   'cooler',
#   'intuitive',
#   '.',
#   'Common',
#   'consumers',
#   'may',
#   'even',
#   'attempt',
#   'fear',
#   'damaging',
#   'something',
#   '.',
#   '1',
#   '.',
#   'Easy',
#   'opening',
#   'side',
#   'frames',
#   'change',
#   'pads',
#   ''],
#  ['',
#   'clean',
#   'water',
#   'inlets2',
#   '.',
#   'Water',
#   'balloon',
#   'used',
#   'cut',
#   'water',
#   'supply',
#   'au',
#   '...',
#   'Excellent',
#   'product',
#   '..',
#   'Happy',
#   'result',
#   '....',
#   'Nice',
#   'air',
#   'flow',
#   '...',
#   'Osm',
#   'cooling',
#   '.....',
#   'cooler',
#   'Works',
#   'Fine',
#   'Inverter',
#   'Friendly',
#   'Small',
#   'wire',
#   'moter',
#   'capacity',
#   'low',
#   'fan',
#   'speed',
#   'good',
#   ''],
#  ['', 'flow', 'vent', 'hole', 'lower', 'part', 'cooler', ''],
#  ['',
#   "'s",
#   'difficult',
#   'change',
#   'water',
#   '.',
#   'Perfect',
#   'product',
#   'large',
#   'size',
#   'room',
#   '.',
#   'Average',
#   'cooling',
#   'much',
#   'expected',
#   'size',
#   'reviews',
#   'cooler',
#   '...',
#   'cooling',
#   'sufficient',
#   'Maharaja',
#   'whiteline',
#   'work',
#   'cooling',
#   'efficiency',
#   'reduce',
#   'size',
#   'width',
#   'increase',
#   'height',
#   'maintain',
#   'tank',
#   'capacity',
#   '.',
#   'Product',
#   'amazing',
#   '..',
#   'cooling',
#   'capacity',
#   'awsum',
#   '.',
#   'Pls',
#   'go',
#   'ahead',
#   '..',
#   'big',
#   'thumbs',
#   '?',
#   'good',
#   'Received',
#   'dalay',
#   '10',
#   'days',
#   '']]

# %%
all_words = [word for sublist in p for word in sublist]
all_words
# Out:
# ['Great',
#  'cooler',
#  '..',
#  'excellent',
#  'air',
#  'flow',
#  'price',
#  '.',
#  "'s",
#  'amazing',
#  'unbelievable.Just',
#  'love',
#  '\x83\x9d',
#  '?',
#  '\x8b',
#  '?',
#  '\x8f',
#  'Best',
#  'budget',
#  '2',
#  'fit',
#  'cooler',
#  '.',
#  'Nice',
#  'cooling',
#  'quality',
#  'good',
#  'power',
#  'air',
#  'decent',
#  'bad',
#  'product',
#  "'s",
#  'fan',
#  'Ok',
#  'ok',
#  'product',
#  'cooler',
#  'really',
#  'fantastic',
#  'provides',
#  'good',
#  'air',
#  'flow',
#  '.',
#  'Highly',
#  'recommended',
#  'good',
#  'product',
#  'nice',
#  'bad',
#  'cooler',
#  'good',
#  'Beautiful',
#  'product',
#  'good',
#  'material',
#  'perfectly',
#  'working',
#  'Awesome',
#  'Good',
#  'Wonderful',
#  'product',
#  '',
#  '',
#  'Must',
#  'buy',
#  'Nice',
#  'air',
#  'cooler',
#  '',
#  '',
#  'smart',
#  'cool',
#  'breeze',
#  'producer',
#  'Awsm',
#  'Nice',
#  'product',
#  '?',
#  '?',
#  '?',
#  '\x8d',
#  'Great',
#  'cooler',
#  '..',
#  'Nice',
#  'product',
#  'Good',
#  '?',
#  '?',
#  '?',
#  '\x8d',
#  'nice',
#  'product',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '?',
#  '\x8d',
#  'Good',
#  'product',
#  'Nice',
#  'product',
#  'reasonable',
#  'price',
#  'like',
#  '...',
#  '\x83\x9d\x9c\x8b',
#  '?',
#  '\x8f',
#  'goodd',
#  'Good',
#  'product',
#  'Good',
#  'product',
#  'kawaleti',
#  'good',
#  'cooler',
#  'amazing',
#  'beautiful',
#  'designs',
#  'affordable',
#  'price',
#  'Using',
#  'since',
#  '3months',
#  '.',
#  'Great',
#  'experience',
#  '.',
#  'good',
#  'performance',
#  'nice',
#  'look',
#  'Product',
#  'good',
#  'strong',
#  'thrust',
#  'air',
#  'flow',
#  '..',
#  'Must',
#  'buy',
#  'good',
#  '?',
#  '?',
#  '?',
#  '\x8d',
#  'Bad',
#  'quality',
#  'nice',
#  '?',
#  '?',
#  '?',
#  '\x8d',
#  'product',
#  'soundless',
#  'product',
#  'low',
#  'price',
#  'company',
#  'Nice',
#  'best',
#  'poduct',
#  'bought',
#  'flifkart',
#  'works',
#  'superb',
#  'like',
#  'ac',
#  'price',
#  'also',
#  'reasonable',
#  'rs',
#  '8698',
#  'cooler',
#  'big',
#  'wide',
#  '.',
#  'maharaja',
#  'brand',
#  'trust',
#  '(',
#  ')',
#  'every',
#  'thing',
#  'good',
#  'cooler',
#  '',
#  '',
#  'create',
#  'less',
#  'noise',
#  '.',
#  'thing',
#  'motor',
#  'powerful',
#  'even',
#  'high',
#  'speed',
#  'rest',
#  'things',
#  'good',
#  '',
#  '',
#  '.but',
#  'yes',
#  'one',
#  'middle',
#  'size',
#  'room',
#  'ok',
#  'one',
#  'best',
#  'air',
#  'coolers',
#  'reasonable',
#  'price',
#  'ever',
#  'seen',
#  'ventilation',
#  'room',
#  'must',
#  'proper',
#  'cooling',
#  'size',
#  'quite',
#  'big',
#  'hope',
#  'create',
#  'space',
#  'problem',
#  'seasons',
#  '...',
#  'air',
#  'supply',
#  'good',
#  "'s",
#  'one',
#  'essential',
#  'part',
#  'air',
#  'cooler',
#  'wool',
#  'wood',
#  'pads',
#  'helps',
#  'make',
#  'super',
#  'cooling',
#  '....',
#  'Afterall',
#  'thank',
#  'Maharaja',
#  'company',
#  'make',
#  'product',
#  'affordable',
#  'reasonable',
#  'price',
#  'Awesome',
#  'Air',
#  'coolerI',
#  'looking',
#  'cooler',
#  'range',
#  'fulfilled',
#  'requirement',
#  '.',
#  'following',
#  'features:1',
#  ')',
#  'Great',
#  'Air',
#  'capacity',
#  '5000',
#  'm3/hr',
#  '2',
#  ')',
#  'Comes',
#  'large',
#  '65-litre',
#  'tank',
#  'run',
#  'overnight',
#  'ease.3',
#  ')',
#  'Great',
#  'built',
#  'shockproof',
#  'reliable',
#  'material.4',
#  ')',
#  'stop',
#  'beast',
#  'night',
#  'massive',
#  'cooling',
#  'capability.One',
#  'small',
#  'concern',
#  'mine',
#  'sure',
#  'deal-breaker',
#  'produces',
#  '...',
#  'Purchased',
#  'lot',
#  'discussions',
#  'reviews',
#  '.',
#  'would',
#  'say',
#  'best',
#  'gives',
#  'comfort',
#  'needed',
#  '.',
#  'Best',
#  '2nd',
#  'thoughts',
#  '.',
#  'Nice',
#  'cooling',
#  '',
#  '',
#  'low',
#  'noise',
#  '.',
#  'Hope',
#  'energy',
#  'efficient',
#  'used',
#  'long',
#  'run',
#  '...',
#  'nice',
#  'cooler',
#  '.',
#  'Cooling',
#  'good',
#  'noise',
#  '.',
#  'reviewed',
#  'lot',
#  'purchased',
#  '.',
#  'want',
#  'effective',
#  'cooling',
#  'set',
#  'window',
#  'cross',
#  'ventilation',
#  '.',
#  'Without',
#  'cross',
#  'ventilation',
#  'make',
#  'environment',
#  'humid',
#  '.',
#  'Lookwise',
#  'nice',
#  'material',
#  'strong',
#  '.',
#  'feedback',
#  'given',
#  'using',
#  'one',
#  'week',
#  '..',
#  'cooler',
#  'amazing',
#  "'s",
#  'making',
#  'whole',
#  'room',
#  'cooling',
#  '..',
#  'install',
#  'cooler',
#  'near',
#  'windows',
#  '..',
#  '&',
#  'delivery',
#  'time',
#  'well',
#  '.the',
#  'delivery',
#  'boy',
#  'also',
#  'supportive',
#  'Great',
#  'deal',
#  '..',
#  '65',
#  'l',
#  'quite',
#  'big',
#  'tank',
#  '.',
#  'Sufficient',
#  'Cooling',
#  'one',
#  'medium',
#  'size',
#  'room',
#  '..',
#  '3',
#  'modes',
#  'works',
#  'well',
#  '..',
#  'best',
#  'range',
#  'bought',
#  'cooler',
#  'heavy',
#  'discount',
#  'flipkart',
#  '.',
#  'Cooler',
#  'build',
#  'good',
#  'quality',
#  'material',
#  '.',
#  'fast',
#  'fan',
#  'powerfull',
#  'motor',
#  'pump',
#  '.',
#  'Air',
#  'quality',
#  'Excellent',
#  'even',
#  'big',
#  'room',
#  '.',
#  'must',
#  'buy',
#  'value',
#  'money',
#  'product',
#  '.',
#  'Good',
#  'things1',
#  '.',
#  'well',
#  'packed',
#  '.',
#  'Good',
#  'amount',
#  'thermocols',
#  'protect',
#  'transport',
#  'damages2',
#  '.',
#  'Sturdy',
#  'body3',
#  '.',
#  'Relatively',
#  'less',
#  'noise',
#  'compared',
#  'Bajaj',
#  'cooler',
#  'earlierWish',
#  'betterFor',
#  'many',
#  'purposes',
#  '',
#  '',
#  'necessary',
#  'open',
#  'Cooler',
#  'body',
#  '.',
#  'Opening',
#  'body',
#  'cooler',
#  'intuitive',
#  '.',
#  'Common',
#  'consumers',
#  'may',
#  'even',
#  'attempt',
#  'fear',
#  'damaging',
#  'something',
#  '.',
#  '1',
#  '.',
#  'Easy',
#  'opening',
#  'side',
#  'frames',
#  'change',
#  'pads',
#  '',
#  '',
#  'clean',
#  'water',
#  'inlets2',
#  '.',
#  'Water',
#  'balloon',
#  'used',
#  'cut',
#  'water',
#  'supply',
#  'au',
#  '...',
#  'Excellent',
#  'product',
#  '..',
#  'Happy',
#  'result',
#  '....',
#  'Nice',
#  'air',
#  'flow',
#  '...',
#  'Osm',
#  'cooling',
#  '.....',
#  'cooler',
#  'Works',
#  'Fine',
#  'Inverter',
#  'Friendly',
#  'Small',
#  'wire',
#  'moter',
#  'capacity',
#  'low',
#  'fan',
#  'speed',
#  'good',
#  '',
#  '',
#  'flow',
#  'vent',
#  'hole',
#  'lower',
#  'part',
#  'cooler',
#  '',
#  '',
#  "'s",
#  'difficult',
#  'change',
#  'water',
#  '.',
#  'Perfect',
#  'product',
#  'large',
#  'size',
#  'room',
#  '.',
#  'Average',
#  'cooling',
#  'much',
#  'expected',
#  'size',
#  'reviews',
#  'cooler',
#  '...',
#  'cooling',
#  'sufficient',
#  'Maharaja',
#  'whiteline',
#  'work',
#  'cooling',
#  'efficiency',
#  'reduce',
#  'size',
#  'width',
#  'increase',
#  'height',
#  'maintain',
#  'tank',
#  'capacity',
#  '.',
#  'Product',
#  'amazing',
#  '..',
#  'cooling',
#  'capacity',
#  'awsum',
#  '.',
#  'Pls',
#  'go',
#  'ahead',
#  '..',
#  'big',
#  'thumbs',
#  '?',
#  'good',
#  'Received',
#  'dalay',
#  '10',
#  'days',
#  '',
#  '',
#  'cooler',
#  'ok',
#  '',
#  '',
#  'reveived',
#  'switch',
#  'damaged',
#  '.',
#  'Big',
#  'one',
#  '',
#  '',
#  'working',
#  'good',
#  '2days',
#  'use',
#  'hope',
#  'work',
#  'long',
#  'run',
#  'good',
#  'product',
#  'nice',
#  'air',
#  'flow',
#  'noice',
#  'price',
#  '..',
#  'Good',
#  'cooler',
#  '..',
#  'good',
#  'many',
#  'awesome',
#  'product',
#  '',
#  '',
#  'light',
#  'weight',
#  '',
#  '',
#  'easy',
#  'use',
#  'lot',
#  'features',
#  'product',
#  "n't",
#  'cool',
#  'rated',
#  'customers',
#  '.',
#  'cooling',
#  'slow',
#  '.',
#  'wrost',
#  'product',
#  '.',
#  'recommend',
#  'buy',
#  'item',
#  '.',
#  'Wastage',
#  'money',
#  '.',
#  'looks',
#  'like',
#  'monster',
#  'cooler',
#  '.',
#  'working',
#  'awesome',
#  'nice',
#  'product',
#  '',
#  '',
#  'Thank',
#  'Flipkart',
#  '.',
#  'good',
#  'Good',
#  'cooler',
#  '.',
#  'occupies',
#  'space',
#  '..',
#  'Looks',
#  'large',
#  'good',
#  'Hall',
#  '..',
#  'covers',
#  'places',
#  '...',
#  'impressive',
#  'cooler.Pros',
#  '-',
#  'Stylish',
#  '',
#  '',
#  'Energy',
#  'efficient',
#  '165',
#  'Watt',
#  '',
#  '',
#  'good',
#  'air',
#  'throw',
#  'cooling',
#  '',
#  '',
#  'Summersible',
#  'pumpCons',
#  '-',
#  'bulky',
#  'take',
#  'place',
#  '',
#  '',
#  'wheel',
#  '',
#  '',
#  'lack',
#  'ice',
#  'box',
#  'Best',
#  'cooler',
#  '.',
#  'bought',
#  '6884/-',
#  'Excellent',
#  'cooler',
#  'price',
#  'range.Pros:1',
#  ')',
#  'Air',
#  'throw',
#  'powerful',
#  'even',
#  'u',
#  'run',
#  'slow',
#  'speed',
#  'setting',
#  '2',
#  ')',
#  'Cooling',
#  'Tank',
#  'capacity3',
#  ')',
#  'Ergonomics',
#  'Cons:1',
#  ')',
#  'want',
#  'clean',
#  'cooler',
#  'opening',
#  'pads',
#  'cumbersome',
#  'process',
#  '.',
#  'placed',
#  'flat',
#  'surface',
#  'also',
#  'draining',
#  'old',
#  'water',
#  'difficult',
#  '.',
#  'Overall',
#  'V',
#  'good',
#  'cooler',
#  'apart',
#  'cons',
#  'considering',
#  'price',
#  '.',
#  'Cooler',
#  'provide',
#  'cool',
#  'air',
#  '...',
#  '1year',
#  'experience',
#  '.',
#  'good',
#  'product',
#  'budget',
#  'packaging',
#  'excellent',
#  '.',
#  'value',
#  'money',
#  'product',
#  '.',
#  'Delivered',
#  'within',
#  '2',
#  'days',
#  '',
#  '',
#  'working',
#  'good',
#  'Efficient',
#  'Large',
#  'RoomsPros-1',
#  '.',
#  'Low',
#  'Noise',
#  'Fan2',
#  '.',
#  'Inverter',
#  'Friendly3',
#  '.',
#  'Cools',
#  'large',
#  'rooms',
#  'fastly',
#  'easily4',
#  '.',
#  'Aroma',
#  'chamber',
#  'add',
#  'tablet',
#  'frangrance',
#  'Counter',
#  'Smell',
#  'Woodwool',
#  'Pads5',
#  '.',
#  '2',
#  'Section',
#  'air',
#  'flow',
#  'means',
#  'adjust',
#  'get',
#  'Air',
#  'double',
#  'decker',
#  'cot',
#  'equally.Cons-1.They',
#  'provided',
#  'stand',
#  'castor',
#  'wheel',
#  'move.2',
#  '.',
#  'Ice',
#  'ChamberWill',
#  'Update',
#  'future',
#  '...',
#  'better',
#  'steel',
#  'cooler',
#  'less',
#  'noise',
#  'value',
#  'money',
#  'dont',
#  'buy',
#  'maharaja',
#  'whiteline',
#  'coolers',
#  '',
#  '',
#  'cheap',
#  'aluminum',
#  'motors',
#  'good',
#  'max',
#  '2',
#  'years',
#  '.',
#  'repair',
#  'cost',
#  'motors',
#  'high',
#  'u',
#  'would',
#  'want',
#  'sell',
#  'rather',
#  'repair',
#  '.',
#  'nice',
#  'product',
#  'delivery',
#  'satisfied',
#  'Quality',
#  'product.1',
#  '.',
#  'wood',
#  'wool',
#  'started',
#  'falling',
#  'next',
#  'day.2',
#  '.',
#  'Two',
#  'Led',
#  '(',
#  'Indicator',
#  ')',
#  'found',
#  'working',
#  'arrival.3',
#  '.',
#  'air',
#  'swinger',
#  'already',
#  'giving',
#  'noise',
#  'moving',
#  'never',
#  'used',
#  'old',
#  'cooler',
#  'using',
#  'since',
#  '3',
#  'years.4',
#  '.',
#  'quality',
#  'way',
#  'machine',
#  '``',
#  'Branded',
#  "''",
#  'coolers.5',
#  '.',
#  'Anti',
#  'bacterial',
#  'tank',
#  'bacterial',
#  'way',
#  'clean',
#  '.',
#  '',
#  '',
#  'congested',
#  'maintain',
#  'cleanly.In',
#  'way',
#  'think',
#  'buy.AC',
#  'option',
#  'Aut',
#  '...',
#  'Air',
#  'throw',
#  'good',
#  '.',
#  'makes',
#  'room',
#  'cool',
#  'half',
#  'hour',
#  '.',
#  'Full',
#  'tank',
#  'capacity',
#  '65',
#  'litres',
#  'stays',
#  '5',
#  'hours',
#  '.',
#  'makes',
#  'big',
#  'living',
#  'room',
#  'colder',
#  '.',
#  'much',
#  'noisy',
#  '.',
#  'time',
#  'delivery',
#  '...',
#  'Received',
#  'exact',
#  'product',
#  ...]

# %%
text1 = ' '.join(all_words)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# %%
plt.figure(figsize=(30, 10))
plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis("off")
plt.show()

# %%
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(text1)

# %%
plt.figure(figsize=(30, 10))
plt.imshow(wordcloud1, interpolation='bilinear')
#plt.axis("off")
plt.show()

# %%
pip install -U textblob

# %%
from textblob import TextBlob

# %% [markdown]
# Function to get sentiment of data i.e. i'm using summary column

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df['sentiment'] = df['Summary'].apply(get_sentiment)

# %% [markdown]
# Grouping sentiment with Review and Price to get the sentiments as +ve or -ve

# %%
Review_sentiment = df.groupby('Review')['sentiment'].mean().reset_index()
print(Review_sentiment)

Price_sentiment = df.groupby('Price')['sentiment'].mean().reset_index()
print(Price_sentiment)
# Out:
#                                                 Review  sentiment
# 0                            "Wise deal for the price"   0.444500
# 1     1) Product quality = 2 stars, Delivery = 5 stars   0.125000
# 2                     100% Satisfied from the Product.   0.436111
# 3                                       2 Thumbs up !!   0.550000
# 4                        2 weeks still no installation   0.500000
# ...                                                ...        ...
# 1260                                     worst product  -0.141667
# 1261             worst service from flipkart this time  -1.000000
# 1262                                      worth buying   0.000000
# 1263                                   worth for money   0.300000
# 1264                                     wrost product   0.105556
#
# [1265 rows x 2 columns]
#                                                  Price  sentiment
# 0                              Bajaj DX 2 L/W Dry Iron  -0.066667
# 1    Nova Plus Amaze NI 10 1100 W Dry Iron?ÿ?ÿ(Grey...  -0.058333
# 2    Pigeon Favourite Electric Kettle?ÿ?ÿ(1.5 L, Si...  -0.166667
# 3                                             ??1,142   0.521803
# 4                                             ??1,155   0.492121
# ..                                                 ...        ...
# 556                                           â¹9,999   0.384646
# 557                                             â¹901   0.389844
# 558                                             â¹949   0.490921
# 559                                              â¹95   0.140768
# 560                                             â¹999   0.432026
#
# [561 rows x 2 columns]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 5))
sns.barplot(x='Review', y='sentiment', data=Review_sentiment)
plt.title('Average Sentiment by Review')
plt.xlabel('Review')
plt.ylabel('Average Sentiment')
plt.show()
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 152 (\x98) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 159 (\x9f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 145 (\x91) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20, 5))
sns.barplot(x='Price', y='sentiment', data=Price_sentiment)
plt.title('Average Sentiment by Price')
plt.xlabel('Price')
plt.ylabel('Average Sentiment')
plt.show()
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ritik\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
